# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('../..')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import warnings

from experiments.experiment_utils import *

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. CARPK

# %%
dataset_name = 'carpk'
experiment_name = 'sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4'
exp_path = f'./{dataset_name}/{experiment_name}/results/quantitative'

res_list = []
for res_path in sorted(os.listdir(exp_path)):
    csv_path = f'{exp_path}/{res_path}/results.csv'
    print(csv_path)
    res_df = pd.read_csv(csv_path, index_col=[3])
    res_list.append(res_df)
# Out:
# ./carpk/sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4/results/quantitative/epoch_01/results.csv
# ./carpk/sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4/results/quantitative/epoch_02/results.csv
# ./carpk/sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4/results/quantitative/epoch_03/results.csv
# ./carpk/sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4/results/quantitative/epoch_04/results.csv
# ./carpk/sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4/results/quantitative/epoch_05/results.csv
# ./carpk/sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4/results/quantitative/epoch_06/results.csv
# ./carpk/sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4/results/quantitative/epoch_07/results.csv
# ./carpk/sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4/results/quantitative/epoch_08/results.csv
# ./carpk/sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4/results/quantitative/epoch_09/results.csv
# ./carpk/sigma_10_loss_logcosh_full_img_epochs_10_lr_1e-4/results/quantitative/epoch_10/results.csv

# %%
def get_results(res_list, metric='MAE', split='train'):
    r = []
    for res_df in res_list:
        value = res_df[metric][split]
        if metric in ['Underestimate', 'Overestimate', 'Difference']:
            value = float(value.split('%')[0])
        r.append(value)
    
    return r

print(get_results(res_list, metric='MAE', split='train'))
print(get_results(res_list, metric='MAE', split='val'))
print(get_results(res_list, metric='MAE', split='test'))
print(get_results(res_list, metric='Difference', split='test'))
# Out:
# [9.384, 3.472, 2.99, 2.327, 2.184, 2.253, 2.09, 1.912, 1.517, 3.07]
# [9.224, 3.365, 3.6319999999999997, 2.574, 2.353, 2.617, 2.552, 1.7890000000000001, 1.882, 3.609]
# [15.702, 9.948, 25.958000000000002, 23.813000000000002, 15.614, 14.904000000000002, 15.037, 14.581, 12.993, 26.38]
# [15.173, 9.613, 25.085, 23.012, 15.089, 14.402, 14.531, 14.09, 12.556, 25.492]

# %%
def plot_results(res_list, metric='', new_figure=True):
    train_res = get_results(res_list, metric=metric, split='train')
    val_res = get_results(res_list, metric=metric, split='val')
    test_res = get_results(res_list, metric=metric, split='test')
    
    if new_figure:
        plt.figure()
    
    plt.title(metric)
    epochs = 1 + np.arange(len(train_res))
    plt.plot(epochs, train_res, label='train')
    plt.plot(epochs, val_res, label='val')
    plt.plot(epochs, test_res, label='test')
    plt.legend()

# %%
plt.figure(figsize=(16, 5))
plt.subplot(1, 2, 1)
plot_results(res_list, metric='MAE', new_figure=False)
plt.subplot(1, 2, 2)
plot_results(res_list, metric='RMSE', new_figure=False)

plt.figure(figsize=(20, 5))
plt.subplot(1, 3, 1)
plot_results(res_list, metric='Underestimate', new_figure=False)
plt.subplot(1, 3, 2)
plot_results(res_list, metric='Overestimate', new_figure=False)
plt.subplot(1, 3, 3)
plot_results(res_list, metric='Difference', new_figure=False)
