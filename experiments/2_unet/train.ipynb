# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('../..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os
import warnings

from keras.callbacks import ModelCheckpoint, Callback
from neural_networks.unet import UNet
from neural_networks.keras_utils import EvalMetricsCallback
from utils.data.data_generator import DataGenerator
from utils.data.data_ops import move_val_split_to_train
from utils.data.data_ops import create_val_split_from_train
from utils.input_output.io import read_json, write_json
from utils.visualization.vis import plot_logs
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load the dataset

# %% [markdown]
# #### Create validation split from the initial training data

# %%
move_val_split_to_train(config.VAL_PATH, config.TRAIN_PATH)
create_val_split_from_train(config.TRAIN_PATH, config.VAL_PATH, config.VAL_SIZE, config.RAND_SEED)

# %%
train_params = {
    'dim': config.PATCH_DIM,
    'batch_size': config.BATCH_SIZE,
    'patches_per_image': config.PATCHES_PER_IMAGE,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': config.SHUFFLE
}

val_params = {
    'dim': config.IMG_DIM,
    'batch_size': 1,
    'patches_per_image': 1,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': False
}

eval_params = val_params.copy()

# %%
train_generator = DataGenerator(config.DATASET_PATH, 'train', **train_params)
val_generator = DataGenerator(config.DATASET_PATH, 'val', **val_params)

### for eval
train_generator_for_eval = DataGenerator(config.DATASET_PATH, 'train', **eval_params)
val_generator_for_eval = DataGenerator(config.DATASET_PATH, 'val', **eval_params)

# %% [markdown]
# ## 3. Instantiate a UNet

# %%
model = UNet(loss_name=config.LOSS_NAME)

# %% [markdown]
# ## 4. Train the model

# %%
# !rm -rf $config.CHECKPOINTS_PATH
# !rm -rf $config.LOGS_PATH
os.makedirs(config.CHECKPOINTS_PATH)
os.makedirs(config.LOGS_PATH)

# %%
# %%time
eval_metrics_callback = EvalMetricsCallback(config.DENSITY_MAP_MULTIPLICATION_FACTOR,
                                            train_generator_for_eval,
                                            val_generator_for_eval)

model_checkpoint = ModelCheckpoint(config.CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   save_best_only=True)

model_history = model.fit_generator(generator=train_generator,
                                    validation_data=val_generator,
                                    epochs=config.EPOCHS,
                                    callbacks=[model_checkpoint,
                                               eval_metrics_callback],
                                    verbose=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 21s 5s/step - loss: 0.4008 - val_loss: 0.1812
# Epoch 2/100
# 4/4 [==============================] - 4s 895ms/step - loss: 0.1608 - val_loss: 0.1400
# Epoch 3/100
# 4/4 [==============================] - 3s 843ms/step - loss: 0.1407 - val_loss: 0.1224
# Epoch 4/100
# 4/4 [==============================] - 4s 880ms/step - loss: 0.1185 - val_loss: 0.1224
# Epoch 5/100
# 4/4 [==============================] - 3s 858ms/step - loss: 0.1068 - val_loss: 0.1131
# Epoch 6/100
# 4/4 [==============================] - 4s 887ms/step - loss: 0.0980 - val_loss: 0.0970
# Epoch 7/100
# 4/4 [==============================] - 3s 834ms/step - loss: 0.0890 - val_loss: 0.0929
# Epoch 8/100
# 4/4 [==============================] - 4s 893ms/step - loss: 0.0830 - val_loss: 0.0887
# Epoch 9/100
# 4/4 [==============================] - 3s 862ms/step - loss: 0.0787 - val_loss: 0.0840
# Epoch 10/100
# 4/4 [==============================] - 3s 822ms/step - loss: 0.0756 - val_loss: 0.0812
# Epoch 11/100
# 4/4 [==============================] - 3s 870ms/step - loss: 0.0749 - val_loss: 0.0759
# Epoch 12/100
# 4/4 [==============================] - 3s 837ms/step - loss: 0.0716 - val_loss: 0.0733
# Epoch 13/100
# 4/4 [==============================] - 4s 883ms/step - loss: 0.0685 - val_loss: 0.0700
# Epoch 14/100
# 4/4 [==============================] - 3s 852ms/step - loss: 0.0647 - val_loss: 0.0654
# Epoch 15/100
# 4/4 [==============================] - 3s 846ms/step - loss: 0.0626 - val_loss: 0.0710
# Epoch 16/100
# 4/4 [==============================] - 4s 888ms/step - loss: 0.0601 - val_loss: 0.0650
# Epoch 17/100
# 4/4 [==============================] - 3s 854ms/step - loss: 0.0580 - val_loss: 0.0583
# Epoch 18/100
# 4/4 [==============================] - 4s 882ms/step - loss: 0.0528 - val_loss: 0.0578
# Epoch 19/100
# 4/4 [==============================] - 4s 931ms/step - loss: 0.0521 - val_loss: 0.0599
# Epoch 20/100
# 4/4 [==============================] - 3s 830ms/step - loss: 0.0534 - val_loss: 0.0573
# Epoch 21/100
# 4/4 [==============================] - 3s 868ms/step - loss: 0.0510 - val_loss: 0.0547
# Epoch 22/100
# 4/4 [==============================] - 3s 856ms/step - loss: 0.0484 - val_loss: 0.0521
# Epoch 23/100
# 4/4 [==============================] - 3s 838ms/step - loss: 0.0459 - val_loss: 0.0520
# Epoch 24/100
# 4/4 [==============================] - 4s 878ms/step - loss: 0.0485 - val_loss: 0.0502
# Epoch 25/100
# 4/4 [==============================] - 4s 891ms/step - loss: 0.0458 - val_loss: 0.0498
# Epoch 26/100
# 4/4 [==============================] - 3s 846ms/step - loss: 0.0453 - val_loss: 0.0492
# Epoch 27/100
# 4/4 [==============================] - 4s 875ms/step - loss: 0.0442 - val_loss: 0.0477
# Epoch 28/100
# 4/4 [==============================] - 3s 839ms/step - loss: 0.0462 - val_loss: 0.0570
# Epoch 29/100
# 4/4 [==============================] - 3s 827ms/step - loss: 0.0458 - val_loss: 0.0495
# Epoch 30/100
# 4/4 [==============================] - 4s 894ms/step - loss: 0.0431 - val_loss: 0.0479
# Epoch 31/100
# 4/4 [==============================] - 3s 862ms/step - loss: 0.0419 - val_loss: 0.0460
# Epoch 32/100
# 4/4 [==============================] - 3s 846ms/step - loss: 0.0405 - val_loss: 0.0473
# Epoch 33/100
# 4/4 [==============================] - 3s 834ms/step - loss: 0.0473 - val_loss: 0.0471
# Epoch 34/100
# 4/4 [==============================] - 3s 862ms/step - loss: 0.0418 - val_loss: 0.0475
# Epoch 35/100
# 4/4 [==============================] - 3s 833ms/step - loss: 0.0421 - val_loss: 0.0451
# Epoch 36/100
# 4/4 [==============================] - 3s 833ms/step - loss: 0.0406 - val_loss: 0.0504
# Epoch 37/100
# 4/4 [==============================] - 4s 880ms/step - loss: 0.0416 - val_loss: 0.0497
# Epoch 38/100
# 4/4 [==============================] - 3s 868ms/step - loss: 0.0429 - val_loss: 0.0442
# Epoch 39/100
# 4/4 [==============================] - 3s 851ms/step - loss: 0.0397 - val_loss: 0.0516
# Epoch 40/100
# 4/4 [==============================] - 3s 869ms/step - loss: 0.0421 - val_loss: 0.0447
# Epoch 41/100
# 4/4 [==============================] - 3s 862ms/step - loss: 0.0401 - val_loss: 0.0466
# Epoch 42/100
# 4/4 [==============================] - 3s 872ms/step - loss: 0.0395 - val_loss: 0.0438
# Epoch 43/100
# 4/4 [==============================] - 3s 854ms/step - loss: 0.0387 - val_loss: 0.0456
# Epoch 44/100
# 4/4 [==============================] - 3s 823ms/step - loss: 0.0385 - val_loss: 0.0443
# Epoch 45/100
# 4/4 [==============================] - 3s 847ms/step - loss: 0.0387 - val_loss: 0.0431
# Epoch 46/100
# 4/4 [==============================] - 4s 876ms/step - loss: 0.0376 - val_loss: 0.0468
# Epoch 47/100
# 4/4 [==============================] - 4s 911ms/step - loss: 0.0376 - val_loss: 0.0437
# Epoch 48/100
# 4/4 [==============================] - 3s 821ms/step - loss: 0.0369 - val_loss: 0.0423
# Epoch 49/100
# 4/4 [==============================] - 3s 843ms/step - loss: 0.0354 - val_loss: 0.0419
# Epoch 50/100
# 4/4 [==============================] - 4s 905ms/step - loss: 0.0356 - val_loss: 0.0442
# Epoch 51/100
# 4/4 [==============================] - 3s 854ms/step - loss: 0.0363 - val_loss: 0.0418
# Epoch 52/100
# 4/4 [==============================] - 3s 858ms/step - loss: 0.0355 - val_loss: 0.0416
# Epoch 53/100
# 4/4 [==============================] - 3s 854ms/step - loss: 0.0336 - val_loss: 0.0421
# Epoch 54/100
# 4/4 [==============================] - 4s 915ms/step - loss: 0.0371 - val_loss: 0.0427
# Epoch 55/100
# 4/4 [==============================] - 3s 844ms/step - loss: 0.0375 - val_loss: 0.0535
# Epoch 56/100
# 4/4 [==============================] - 3s 867ms/step - loss: 0.0424 - val_loss: 0.0430
# Epoch 57/100
# 4/4 [==============================] - 4s 876ms/step - loss: 0.0370 - val_loss: 0.0478
# Epoch 58/100
# 4/4 [==============================] - 3s 849ms/step - loss: 0.0381 - val_loss: 0.0432
# Epoch 59/100
# 4/4 [==============================] - 4s 882ms/step - loss: 0.0358 - val_loss: 0.0433
# Epoch 60/100
# 4/4 [==============================] - 3s 825ms/step - loss: 0.0343 - val_loss: 0.0426
# Epoch 61/100
# 4/4 [==============================] - 4s 910ms/step - loss: 0.0334 - val_loss: 0.0425
# Epoch 62/100
# 4/4 [==============================] - 3s 848ms/step - loss: 0.0322 - val_loss: 0.0418
# Epoch 63/100
# 4/4 [==============================] - 4s 894ms/step - loss: 0.0313 - val_loss: 0.0410
# Epoch 64/100
# 4/4 [==============================] - 4s 893ms/step - loss: 0.0308 - val_loss: 0.0440
# Epoch 65/100
# 4/4 [==============================] - 3s 846ms/step - loss: 0.0361 - val_loss: 0.0498
# Epoch 66/100
# 4/4 [==============================] - 3s 857ms/step - loss: 0.0381 - val_loss: 0.0432
# Epoch 67/100
# 4/4 [==============================] - 3s 836ms/step - loss: 0.0414 - val_loss: 0.0452
# Epoch 68/100
# 4/4 [==============================] - 3s 855ms/step - loss: 0.0382 - val_loss: 0.0425
# Epoch 69/100
# 4/4 [==============================] - 4s 913ms/step - loss: 0.0342 - val_loss: 0.0437
# Epoch 70/100
# 4/4 [==============================] - 3s 846ms/step - loss: 0.0327 - val_loss: 0.0423
# Epoch 71/100
# 4/4 [==============================] - 3s 838ms/step - loss: 0.0312 - val_loss: 0.0428
# Epoch 72/100
# 4/4 [==============================] - 3s 826ms/step - loss: 0.0306 - val_loss: 0.0430
# Epoch 73/100
# 4/4 [==============================] - 3s 850ms/step - loss: 0.0315 - val_loss: 0.0418
# Epoch 74/100
# 4/4 [==============================] - 3s 819ms/step - loss: 0.0323 - val_loss: 0.0421
# Epoch 75/100
# 4/4 [==============================] - 4s 893ms/step - loss: 0.0294 - val_loss: 0.0412
# Epoch 76/100
# 4/4 [==============================] - 3s 868ms/step - loss: 0.0313 - val_loss: 0.0411
# Epoch 77/100
# 4/4 [==============================] - 3s 828ms/step - loss: 0.0320 - val_loss: 0.0411
# Epoch 78/100
# 4/4 [==============================] - 3s 856ms/step - loss: 0.0306 - val_loss: 0.0413
# Epoch 79/100
# 4/4 [==============================] - 3s 847ms/step - loss: 0.0294 - val_loss: 0.0422
# Epoch 80/100
# 4/4 [==============================] - 4s 882ms/step - loss: 0.0281 - val_loss: 0.0412
# Epoch 81/100
# 4/4 [==============================] - 4s 934ms/step - loss: 0.0299 - val_loss: 0.0413
# Epoch 82/100
# 4/4 [==============================] - 4s 878ms/step - loss: 0.0287 - val_loss: 0.0471
# Epoch 83/100
# 4/4 [==============================] - 3s 832ms/step - loss: 0.0311 - val_loss: 0.0561
# Epoch 84/100
# 4/4 [==============================] - 3s 857ms/step - loss: 0.0427 - val_loss: 0.0507
# Epoch 85/100
# 4/4 [==============================] - 3s 834ms/step - loss: 0.0383 - val_loss: 0.0449
# Epoch 86/100
# 4/4 [==============================] - 3s 839ms/step - loss: 0.0359 - val_loss: 0.0465
# Epoch 87/100
# 4/4 [==============================] - 3s 859ms/step - loss: 0.0329 - val_loss: 0.0460
# Epoch 88/100
# 4/4 [==============================] - 3s 861ms/step - loss: 0.0330 - val_loss: 0.0426
# Epoch 89/100
# 4/4 [==============================] - 3s 822ms/step - loss: 0.0319 - val_loss: 0.0419
# Epoch 90/100
# 4/4 [==============================] - 3s 821ms/step - loss: 0.0311 - val_loss: 0.0423
# Epoch 91/100
# 4/4 [==============================] - 4s 897ms/step - loss: 0.0288 - val_loss: 0.0432
# Epoch 92/100
# 4/4 [==============================] - 3s 869ms/step - loss: 0.0277 - val_loss: 0.0413
# Epoch 93/100
# 4/4 [==============================] - 3s 843ms/step - loss: 0.0281 - val_loss: 0.0432
# Epoch 94/100
# 4/4 [==============================] - 3s 860ms/step - loss: 0.0264 - val_loss: 0.0411
# Epoch 95/100
# 4/4 [==============================] - 3s 865ms/step - loss: 0.0254 - val_loss: 0.0435
# Epoch 96/100
# 4/4 [==============================] - 3s 855ms/step - loss: 0.0258 - val_loss: 0.0410
# Epoch 97/100
# 4/4 [==============================] - 3s 858ms/step - loss: 0.0238 - val_loss: 0.0413
# Epoch 98/100
# 4/4 [==============================] - 3s 861ms/step - loss: 0.0258 - val_loss: 0.0439
# Epoch 99/100
# 4/4 [==============================] - 3s 830ms/step - loss: 0.0245 - val_loss: 0.0406
# Epoch 100/100
# 4/4 [==============================] - 4s 905ms/step - loss: 0.0266 - val_loss: 0.0412
# CPU times: user 16min 28s, sys: 1min 10s, total: 17min 39s
# Wall time: 12min 44s

# %% [markdown]
# #### Save and load train stats/logs/history

# %%
logs = model.history.history.copy()

logs['train_loss'] = logs.pop('loss')
logs['train_size'] = train_generator.get_size()
logs['val_size'] = val_generator.get_size()
logs['rand_seed'] = config.RAND_SEED
logs['shuffle'] = config.SHUFFLE
logs['loss_name'] = config.LOSS_NAME
logs['img_dim'] = config.IMG_DIM
logs['patch_dim'] = config.PATCH_DIM
logs['patches_per_image'] = config.PATCHES_PER_IMAGE
logs['density_map_sigma'] = config.GT_SIGMA
logs['density_map_multiplication_factor'] = config.DENSITY_MAP_MULTIPLICATION_FACTOR
logs['sub_experiment_name'] = config.SUB_EXPERIMENT_NAME
logs['architecture'] = config.ARCHITECTURE_NAME

# %%
write_json(logs, config.LOGS_FILENAME)
logs = read_json(config.LOGS_FILENAME)

print(f'min val_loss: {np.min(logs["val_loss"]):.4f}, epoch: {1 + np.argmin(logs["val_loss"])}')

plot_logs(logs['train_loss'], logs['val_loss'], f'{config.LOSS_NAME} loss (density maps)')

plot_logs(logs['train_mae'], logs['val_mae'], f'Mean_absolute_error (counts)')
plot_logs(logs['train_rmse'], logs['val_rmse'], f'RMSE (counts)')
plot_logs(logs['train_underestimate'], logs['val_underestimate'], f'Underestimate (% from GT counts)')
plot_logs(logs['train_overestimate'], logs['val_overestimate'], f'Overestimate (% from GT counts)')
plot_logs(logs['train_difference'], logs['val_difference'], f'Difference (% from GT counts)')
# Out:
# min val_loss: 0.0406, epoch: 99
