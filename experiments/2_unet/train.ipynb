# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('../..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os
import warnings

from keras.callbacks import ModelCheckpoint, Callback
from neural_networks.unet import UNet
from neural_networks.keras_utils import EvalMetricsCallback
from utils.data.data_generator import DataGenerator
from utils.data.data_ops import move_val_split_to_train
from utils.data.data_ops import create_val_split_from_train
from utils.input_output.io import read_json, write_json
from utils.visualization.vis import plot_logs
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load the dataset

# %% [markdown]
# #### Create validation split from the initial training data

# %%
move_val_split_to_train(config.VAL_PATH, config.TRAIN_PATH)
create_val_split_from_train(config.TRAIN_PATH, config.VAL_PATH, config.VAL_SIZE, config.RAND_SEED)

# %%
train_params = {
    'dim': config.PATCH_DIM,
    'batch_size': config.BATCH_SIZE,
    'patches_per_image': config.PATCHES_PER_IMAGE,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': config.SHUFFLE,
    'ignored_images': config.IGNORED_IMAGES
}

val_params = {
    'dim': config.IMG_DIM,
    'batch_size': 1,
    'patches_per_image': 1,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': False
}

eval_params = val_params.copy()

# %%
train_generator = DataGenerator(config.DATASET_PATH, 'train', **train_params)
val_generator = DataGenerator(config.DATASET_PATH, 'val', **val_params)

### for eval
train_generator_for_eval = DataGenerator(config.DATASET_PATH, 'train', **eval_params)
val_generator_for_eval = DataGenerator(config.DATASET_PATH, 'val', **eval_params)

# %% [markdown]
# ## 3. Instantiate a UNet

# %%
model = UNet(loss_name=config.LOSS_NAME)

# %% [markdown]
# ## 4. Train the model

# %%
# !rm -rf $config.CHECKPOINTS_PATH
# !rm -rf $config.LOGS_PATH
os.makedirs(config.CHECKPOINTS_PATH)
os.makedirs(config.LOGS_PATH)

# %%
# %%time
eval_metrics_callback = EvalMetricsCallback(config.DENSITY_MAP_MULTIPLICATION_FACTOR,
                                            train_generator_for_eval,
                                            val_generator_for_eval)

model_checkpoint = ModelCheckpoint(config.CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   save_best_only=True)

model_history = model.fit_generator(generator=train_generator,
                                    validation_data=val_generator,
                                    epochs=config.EPOCHS,
                                    callbacks=[model_checkpoint,
                                               eval_metrics_callback],
                                    verbose=1)
# Out:
# Epoch 1/50
# 319/319 [==============================] - 112s 352ms/step - loss: 1.0337 - val_loss: 1.1879
# Epoch 2/50
# 319/319 [==============================] - 104s 326ms/step - loss: 0.8863 - val_loss: 1.3776
# Epoch 3/50
# 319/319 [==============================] - 104s 326ms/step - loss: 1.1452 - val_loss: 1.4030
# Epoch 4/50
# 319/319 [==============================] - 104s 327ms/step - loss: 0.9042 - val_loss: 1.2690
# Epoch 5/50
# 319/319 [==============================] - 105s 328ms/step - loss: 0.8760 - val_loss: 1.4336
# Epoch 6/50
# 319/319 [==============================] - 104s 327ms/step - loss: 1.0437 - val_loss: 1.4329
# Epoch 7/50
# 319/319 [==============================] - 105s 328ms/step - loss: 1.1856 - val_loss: 1.3672
# Epoch 8/50
# 319/319 [==============================] - 105s 328ms/step - loss: 0.9961 - val_loss: 1.3552
# Epoch 9/50
# 319/319 [==============================] - 105s 329ms/step - loss: 1.0447 - val_loss: 1.3252
# Epoch 10/50
# 319/319 [==============================] - 104s 327ms/step - loss: 0.8089 - val_loss: 1.3056
# Epoch 11/50
# 319/319 [==============================] - 105s 328ms/step - loss: 0.9507 - val_loss: 1.2523
# Epoch 12/50
# 319/319 [==============================] - 104s 327ms/step - loss: 1.0119 - val_loss: 1.2918
# Epoch 13/50
# 319/319 [==============================] - 104s 327ms/step - loss: 0.8905 - val_loss: 1.2808
# Epoch 14/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.9097 - val_loss: 1.2876
# Epoch 15/50
# 319/319 [==============================] - 105s 328ms/step - loss: 0.9271 - val_loss: 1.3198
# Epoch 16/50
# 319/319 [==============================] - 105s 328ms/step - loss: 0.8369 - val_loss: 1.0949
# Epoch 17/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.8055 - val_loss: 1.0206
# Epoch 18/50
# 319/319 [==============================] - 105s 328ms/step - loss: 0.9260 - val_loss: 1.1398
# Epoch 19/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.8128 - val_loss: 1.0679
# Epoch 20/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.8087 - val_loss: 1.1637
# Epoch 21/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.8046 - val_loss: 1.0666
# Epoch 22/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.8056 - val_loss: 0.9933
# Epoch 23/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.7364 - val_loss: 0.8488
# Epoch 24/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.7714 - val_loss: 0.8498
# Epoch 25/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.6180 - val_loss: 0.9259
# Epoch 26/50
# 319/319 [==============================] - 104s 327ms/step - loss: 0.7685 - val_loss: 0.8716
# Epoch 27/50
# 319/319 [==============================] - 104s 327ms/step - loss: 0.6425 - val_loss: 0.7036
# Epoch 28/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.6298 - val_loss: 0.8826
# Epoch 29/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.7863 - val_loss: 0.9922
# Epoch 30/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.6454 - val_loss: 0.7257
# Epoch 31/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.6153 - val_loss: 0.6843
# Epoch 32/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.5111 - val_loss: 0.6776
# Epoch 33/50
# 319/319 [==============================] - 105s 328ms/step - loss: 0.8097 - val_loss: 0.7720
# Epoch 34/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.5665 - val_loss: 0.8336
# Epoch 35/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.7430 - val_loss: 0.8656
# Epoch 36/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.5542 - val_loss: 0.6894
# Epoch 37/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.5920 - val_loss: 0.7207
# Epoch 38/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.5901 - val_loss: 0.6556
# Epoch 39/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.5198 - val_loss: 0.6157
# Epoch 40/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.5302 - val_loss: 0.6101
# Epoch 41/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.6069 - val_loss: 1.0709
# Epoch 42/50
# 319/319 [==============================] - 104s 327ms/step - loss: 0.5364 - val_loss: 0.5944
# Epoch 43/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.4964 - val_loss: 0.6152
# Epoch 44/50
# 319/319 [==============================] - 105s 328ms/step - loss: 0.5642 - val_loss: 0.7062
# Epoch 45/50
# 319/319 [==============================] - 104s 327ms/step - loss: 0.5955 - val_loss: 0.6191
# Epoch 46/50
# 319/319 [==============================] - 104s 327ms/step - loss: 0.4162 - val_loss: 0.5712
# Epoch 47/50
# 319/319 [==============================] - 105s 328ms/step - loss: 0.4805 - val_loss: 0.5993
# Epoch 48/50
# 319/319 [==============================] - 104s 327ms/step - loss: 0.4828 - val_loss: 0.5467
# Epoch 49/50
# 319/319 [==============================] - 105s 328ms/step - loss: 0.5784 - val_loss: 0.6285
# Epoch 50/50
# 319/319 [==============================] - 105s 329ms/step - loss: 0.5157 - val_loss: 0.5293
# CPU times: user 2h 26s, sys: 23min 3s, total: 2h 23min 29s
# Wall time: 2h 30min 45s

# %% [markdown]
# #### Save and load train stats/logs/history

# %%
logs = model.history.history.copy()

logs['train_loss'] = logs.pop('loss')
logs['train_size'] = train_generator.get_size()
logs['val_size'] = val_generator.get_size()
logs['rand_seed'] = config.RAND_SEED
logs['shuffle'] = config.SHUFFLE
logs['loss_name'] = config.LOSS_NAME
logs['img_dim'] = config.IMG_DIM
logs['patch_dim'] = config.PATCH_DIM
logs['patches_per_image'] = config.PATCHES_PER_IMAGE
logs['density_map_sigma'] = config.GT_SIGMA
logs['density_map_multiplication_factor'] = config.DENSITY_MAP_MULTIPLICATION_FACTOR
logs['sub_experiment_name'] = config.SUB_EXPERIMENT_NAME
logs['architecture'] = config.ARCHITECTURE_NAME

# %%
write_json(logs, config.LOGS_FILENAME)
logs = read_json(config.LOGS_FILENAME)

print(f'min val_loss: {np.min(logs["val_loss"]):.4f}, epoch: {1 + np.argmin(logs["val_loss"])}')

plot_logs(logs['train_loss'], logs['val_loss'], f'{config.LOSS_NAME} loss (density maps)')

plot_logs(logs['train_mae'], logs['val_mae'], f'Mean_absolute_error (counts)')
plot_logs(logs['train_rmse'], logs['val_rmse'], f'RMSE (counts)')
plot_logs(logs['train_underestimate'], logs['val_underestimate'], f'Underestimate (% from GT counts)')
plot_logs(logs['train_overestimate'], logs['val_overestimate'], f'Overestimate (% from GT counts)')
plot_logs(logs['train_difference'], logs['val_difference'], f'Difference (% from GT counts)')
# Out:
# min val_loss: 0.5293, epoch: 50
