# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('../..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os
import warnings

from keras.callbacks import ModelCheckpoint, Callback
from neural_networks.unet import UNet
from neural_networks.keras_utils import EvalMetricsCallback
from utils.data.data_generator import DataGenerator
from utils.data.data_ops import move_val_split_to_train
from utils.data.data_ops import create_val_split_from_train
from utils.input_output.io import read_json, write_json
from utils.visualization.vis import plot_logs
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load the dataset

# %% [markdown]
# #### Create validation split from the initial training data

# %%
move_val_split_to_train(config.VAL_PATH, config.TRAIN_PATH)
create_val_split_from_train(config.TRAIN_PATH, config.VAL_PATH, config.VAL_SIZE, config.RAND_SEED)

# %%
train_params = {
    'dim': config.PATCH_DIM,
    'batch_size': config.BATCH_SIZE,
    'patches_per_image': config.PATCHES_PER_IMAGE,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': config.SHUFFLE,
    'ignored_images': config.IGNORED_IMAGES
}

val_params = {
    'dim': config.IMG_DIM,
    'batch_size': 1,
    'patches_per_image': 1,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': False
}

eval_params = val_params.copy()

# %%
train_generator = DataGenerator(config.DATASET_PATH, 'train', **train_params)
val_generator = DataGenerator(config.DATASET_PATH, 'val', **val_params)

### for eval
train_generator_for_eval = DataGenerator(config.DATASET_PATH, 'train', **eval_params)
val_generator_for_eval = DataGenerator(config.DATASET_PATH, 'val', **eval_params)

# %% [markdown]
# ## 3. Instantiate a UNet

# %%
model = UNet(loss_name=config.LOSS_NAME)

# %% [markdown]
# ## 4. Train the model

# %%
# !rm -rf $config.CHECKPOINTS_PATH
# !rm -rf $config.LOGS_PATH
os.makedirs(config.CHECKPOINTS_PATH)
os.makedirs(config.LOGS_PATH)

# %%
# %%time
eval_metrics_callback = EvalMetricsCallback(config.DENSITY_MAP_MULTIPLICATION_FACTOR,
                                            train_generator_for_eval,
                                            val_generator_for_eval)

model_checkpoint = ModelCheckpoint(config.CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   save_best_only=True)

model_history = model.fit_generator(generator=train_generator,
                                    validation_data=val_generator,
                                    epochs=config.EPOCHS,
                                    callbacks=[model_checkpoint,
                                               eval_metrics_callback],
                                    verbose=1)
# Out:
# Epoch 1/50
# 319/319 [==============================] - 169s 529ms/step - loss: 0.2295 - val_loss: 0.1873
# Epoch 2/50
# 319/319 [==============================] - 160s 503ms/step - loss: 0.2167 - val_loss: 0.1811
# Epoch 3/50
# 319/319 [==============================] - 160s 501ms/step - loss: 0.2047 - val_loss: 0.1925
# Epoch 4/50
# 319/319 [==============================] - 160s 503ms/step - loss: 0.1825 - val_loss: 0.1440
# Epoch 5/50
# 319/319 [==============================] - 160s 503ms/step - loss: 0.1676 - val_loss: 0.1675
# Epoch 6/50
# 319/319 [==============================] - 160s 501ms/step - loss: 0.1525 - val_loss: 0.1299
# Epoch 7/50
# 319/319 [==============================] - 160s 501ms/step - loss: 0.1497 - val_loss: 0.1432
# Epoch 8/50
# 319/319 [==============================] - 160s 501ms/step - loss: 0.1349 - val_loss: 0.1180
# Epoch 9/50
# 319/319 [==============================] - 160s 501ms/step - loss: 0.1354 - val_loss: 0.1191
# Epoch 10/50
# 319/319 [==============================] - 160s 502ms/step - loss: 0.1211 - val_loss: 0.1221
# Epoch 11/50
# 319/319 [==============================] - 160s 502ms/step - loss: 0.1263 - val_loss: 0.1106
# Epoch 12/50
# 319/319 [==============================] - 160s 503ms/step - loss: 0.1108 - val_loss: 0.1086
# Epoch 13/50
# 319/319 [==============================] - 161s 504ms/step - loss: 0.1042 - val_loss: 0.1017
# Epoch 14/50
# 319/319 [==============================] - 161s 505ms/step - loss: 0.1064 - val_loss: 0.1067
# Epoch 15/50
# 319/319 [==============================] - 161s 505ms/step - loss: 0.1063 - val_loss: 0.1004
# Epoch 16/50
# 319/319 [==============================] - 161s 506ms/step - loss: 0.0901 - val_loss: 0.0929
# Epoch 17/50
# 319/319 [==============================] - 161s 506ms/step - loss: 0.0942 - val_loss: 0.0947
# Epoch 18/50
# 319/319 [==============================] - 162s 506ms/step - loss: 0.0894 - val_loss: 0.0887
# Epoch 19/50
# 319/319 [==============================] - 162s 507ms/step - loss: 0.0793 - val_loss: 0.1039
# Epoch 20/50
# 319/319 [==============================] - 162s 508ms/step - loss: 0.0763 - val_loss: 0.0884
# Epoch 21/50
# 319/319 [==============================] - 162s 508ms/step - loss: 0.0780 - val_loss: 0.0963
# Epoch 22/50
# 319/319 [==============================] - 162s 508ms/step - loss: 0.0733 - val_loss: 0.0951
# Epoch 23/50
# 319/319 [==============================] - 162s 508ms/step - loss: 0.0704 - val_loss: 0.0899
# Epoch 24/50
# 319/319 [==============================] - 162s 509ms/step - loss: 0.0684 - val_loss: 0.0876
# Epoch 25/50
# 319/319 [==============================] - 162s 509ms/step - loss: 0.0581 - val_loss: 0.0960
# Epoch 26/50
# 319/319 [==============================] - 162s 509ms/step - loss: 0.0597 - val_loss: 0.0894
# Epoch 27/50
# 319/319 [==============================] - 162s 507ms/step - loss: 0.0530 - val_loss: 0.0946
# Epoch 28/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0564 - val_loss: 0.1017
# Epoch 29/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0611 - val_loss: 0.1201
# Epoch 30/50
# 319/319 [==============================] - 162s 506ms/step - loss: 0.0543 - val_loss: 0.0935
# Epoch 31/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0498 - val_loss: 0.0874
# Epoch 32/50
# 319/319 [==============================] - 162s 509ms/step - loss: 0.0465 - val_loss: 0.0880
# Epoch 33/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0579 - val_loss: 0.1008
# Epoch 34/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0413 - val_loss: 0.1019
# Epoch 35/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0410 - val_loss: 0.0878
# Epoch 36/50
# 319/319 [==============================] - 162s 509ms/step - loss: 0.0405 - val_loss: 0.0893
# Epoch 37/50
# 319/319 [==============================] - 163s 509ms/step - loss: 0.0392 - val_loss: 0.1051
# Epoch 38/50
# 319/319 [==============================] - 162s 509ms/step - loss: 0.0452 - val_loss: 0.0926
# Epoch 39/50
# 319/319 [==============================] - 163s 509ms/step - loss: 0.0448 - val_loss: 0.1117
# Epoch 40/50
# 319/319 [==============================] - 162s 509ms/step - loss: 0.0389 - val_loss: 0.0903
# Epoch 41/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0361 - val_loss: 0.0896
# Epoch 42/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0328 - val_loss: 0.0889
# Epoch 43/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0310 - val_loss: 0.0910
# Epoch 44/50
# 319/319 [==============================] - 162s 507ms/step - loss: 0.0355 - val_loss: 0.0993
# Epoch 45/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0356 - val_loss: 0.0897
# Epoch 46/50
# 319/319 [==============================] - 163s 511ms/step - loss: 0.0339 - val_loss: 0.0899
# Epoch 47/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0286 - val_loss: 0.0911
# Epoch 48/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.0273 - val_loss: 0.0907
# Epoch 49/50
# 319/319 [==============================] - 163s 512ms/step - loss: 0.0280 - val_loss: 0.0889
# Epoch 50/50
# 319/319 [==============================] - 162s 509ms/step - loss: 0.0286 - val_loss: 0.0936
# CPU times: user 2h 28min 23s, sys: 29min 28s, total: 2h 57min 52s
# Wall time: 3h 18min 6s

# %% [markdown]
# #### Save and load train stats/logs/history

# %%
logs = model.history.history.copy()

logs['train_loss'] = logs.pop('loss')
logs['train_size'] = train_generator.get_size()
logs['val_size'] = val_generator.get_size()
logs['rand_seed'] = config.RAND_SEED
logs['shuffle'] = config.SHUFFLE
logs['loss_name'] = config.LOSS_NAME
logs['img_dim'] = config.IMG_DIM
logs['patch_dim'] = config.PATCH_DIM
logs['patches_per_image'] = config.PATCHES_PER_IMAGE
logs['density_map_sigma'] = config.GT_SIGMA
logs['density_map_multiplication_factor'] = config.DENSITY_MAP_MULTIPLICATION_FACTOR
logs['sub_experiment_name'] = config.SUB_EXPERIMENT_NAME
logs['architecture'] = config.ARCHITECTURE_NAME

# %%
write_json(logs, config.LOGS_FILENAME)
logs = read_json(config.LOGS_FILENAME)

print(f'min val_loss: {np.min(logs["val_loss"]):.4f}, epoch: {1 + np.argmin(logs["val_loss"])}')

plot_logs(logs['train_loss'], logs['val_loss'], f'{config.LOSS_NAME} loss (density maps)')

plot_logs(logs['train_mae'], logs['val_mae'], f'Mean_absolute_error (counts)')
plot_logs(logs['train_rmse'], logs['val_rmse'], f'RMSE (counts)')
plot_logs(logs['train_underestimate'], logs['val_underestimate'], f'Underestimate (% from GT counts)')
plot_logs(logs['train_overestimate'], logs['val_overestimate'], f'Overestimate (% from GT counts)')
plot_logs(logs['train_difference'], logs['val_difference'], f'Difference (% from GT counts)')
# Out:
# min val_loss: 0.0874, epoch: 31
