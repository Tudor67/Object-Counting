# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('../..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os
import warnings

from keras.callbacks import ModelCheckpoint, Callback
from neural_networks.unet import UNet
from neural_networks.keras_utils import EvalMetricsCallback
from utils.data.data_generator import DataGenerator
from utils.data.data_ops import move_val_split_to_train
from utils.data.data_ops import create_val_split_from_train
from utils.input_output.io import read_json, write_json
from utils.visualization.vis import plot_logs
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load the dataset

# %% [markdown]
# #### Create validation split from the initial training data

# %%
move_val_split_to_train(config.VAL_PATH, config.TRAIN_PATH)
create_val_split_from_train(config.TRAIN_PATH, config.VAL_PATH, config.VAL_SIZE, config.RAND_SEED)

# %%
train_params = {
    'dim': config.PATCH_DIM,
    'batch_size': config.BATCH_SIZE,
    'patches_per_image': config.PATCHES_PER_IMAGE,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': config.SHUFFLE,
    'ignored_images': config.IGNORED_IMAGES
}

val_params = {
    'dim': config.IMG_DIM,
    'batch_size': 1,
    'patches_per_image': 1,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': False
}

eval_params = val_params.copy()

# %%
train_generator = DataGenerator(config.DATASET_PATH, 'train', **train_params)
val_generator = DataGenerator(config.DATASET_PATH, 'val', **val_params)

### for eval
train_generator_for_eval = DataGenerator(config.DATASET_PATH, 'train', **eval_params)
val_generator_for_eval = DataGenerator(config.DATASET_PATH, 'val', **eval_params)

# %% [markdown]
# ## 3. Instantiate a UNet

# %%
model = UNet(loss_name=config.LOSS_NAME)

# %% [markdown]
# ## 4. Train the model

# %%
# !rm -rf $config.CHECKPOINTS_PATH
# !rm -rf $config.LOGS_PATH
os.makedirs(config.CHECKPOINTS_PATH)
os.makedirs(config.LOGS_PATH)

# %%
# %%time
eval_metrics_callback = EvalMetricsCallback(config.DENSITY_MAP_MULTIPLICATION_FACTOR,
                                            train_generator_for_eval,
                                            val_generator_for_eval)

model_checkpoint = ModelCheckpoint(config.CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   save_best_only=True)

model_history = model.fit_generator(generator=train_generator,
                                    validation_data=val_generator,
                                    epochs=config.EPOCHS,
                                    callbacks=[model_checkpoint,
                                               eval_metrics_callback],
                                    verbose=1)
# Out:
# Epoch 1/50
# 319/319 [==============================] - 171s 535ms/step - loss: 1.8403 - val_loss: 1.4288
# Epoch 2/50
# 319/319 [==============================] - 161s 506ms/step - loss: 1.7318 - val_loss: 1.4248
# Epoch 3/50
# 319/319 [==============================] - 161s 505ms/step - loss: 1.7537 - val_loss: 1.4608
# Epoch 4/50
# 319/319 [==============================] - 161s 504ms/step - loss: 1.6485 - val_loss: 1.1274
# Epoch 5/50
# 319/319 [==============================] - 162s 508ms/step - loss: 1.4788 - val_loss: 1.0839
# Epoch 6/50
# 319/319 [==============================] - 161s 506ms/step - loss: 1.7223 - val_loss: 1.1534
# Epoch 7/50
# 319/319 [==============================] - 163s 510ms/step - loss: 1.4964 - val_loss: 1.2773
# Epoch 8/50
# 319/319 [==============================] - 161s 505ms/step - loss: 1.4201 - val_loss: 0.9326
# Epoch 9/50
# 319/319 [==============================] - 162s 507ms/step - loss: 1.2717 - val_loss: 0.8289
# Epoch 10/50
# 319/319 [==============================] - 162s 508ms/step - loss: 1.3841 - val_loss: 0.9396
# Epoch 11/50
# 319/319 [==============================] - 163s 510ms/step - loss: 1.2678 - val_loss: 0.9741
# Epoch 12/50
# 319/319 [==============================] - 163s 510ms/step - loss: 1.2445 - val_loss: 0.9208
# Epoch 13/50
# 319/319 [==============================] - 161s 505ms/step - loss: 1.2550 - val_loss: 1.0380
# Epoch 14/50
# 319/319 [==============================] - 163s 511ms/step - loss: 1.2409 - val_loss: 0.8853
# Epoch 15/50
# 319/319 [==============================] - 161s 505ms/step - loss: 1.4762 - val_loss: 1.4202
# Epoch 16/50
# 319/319 [==============================] - 159s 500ms/step - loss: 1.8656 - val_loss: 1.4244
# Epoch 17/50
# 319/319 [==============================] - 158s 494ms/step - loss: 1.8750 - val_loss: 1.4239
# Epoch 18/50
# 319/319 [==============================] - 158s 496ms/step - loss: 1.8521 - val_loss: 1.2734
# Epoch 19/50
# 319/319 [==============================] - 158s 495ms/step - loss: 1.4748 - val_loss: 1.0993
# Epoch 20/50
# 319/319 [==============================] - 158s 497ms/step - loss: 1.3560 - val_loss: 1.1744
# Epoch 21/50
# 319/319 [==============================] - 161s 504ms/step - loss: 1.4935 - val_loss: 1.3629
# Epoch 22/50
# 319/319 [==============================] - 161s 505ms/step - loss: 1.3775 - val_loss: 0.8402
# Epoch 23/50
# 319/319 [==============================] - 161s 504ms/step - loss: 1.1381 - val_loss: 0.9386
# Epoch 24/50
# 319/319 [==============================] - 161s 506ms/step - loss: 1.1890 - val_loss: 0.9270
# Epoch 25/50
# 319/319 [==============================] - 161s 506ms/step - loss: 1.1055 - val_loss: 0.7449
# Epoch 26/50
# 319/319 [==============================] - 162s 507ms/step - loss: 1.0895 - val_loss: 0.7169
# Epoch 27/50
# 319/319 [==============================] - 162s 507ms/step - loss: 1.0172 - val_loss: 0.7566
# Epoch 28/50
# 319/319 [==============================] - 162s 508ms/step - loss: 0.8880 - val_loss: 0.7043
# Epoch 29/50
# 319/319 [==============================] - 162s 507ms/step - loss: 0.8729 - val_loss: 0.9513
# Epoch 30/50
# 319/319 [==============================] - 162s 509ms/step - loss: 0.9515 - val_loss: 0.6640
# Epoch 31/50
# 319/319 [==============================] - 162s 509ms/step - loss: 0.8167 - val_loss: 0.6584
# Epoch 32/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.6762 - val_loss: 0.6184
# Epoch 33/50
# 319/319 [==============================] - 163s 511ms/step - loss: 0.6981 - val_loss: 1.0499
# Epoch 34/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.8552 - val_loss: 0.6505
# Epoch 35/50
# 319/319 [==============================] - 163s 511ms/step - loss: 0.6647 - val_loss: 0.5801
# Epoch 36/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.5938 - val_loss: 0.5938
# Epoch 37/50
# 319/319 [==============================] - 162s 507ms/step - loss: 0.5289 - val_loss: 0.5605
# Epoch 38/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.5309 - val_loss: 0.6476
# Epoch 39/50
# 319/319 [==============================] - 162s 507ms/step - loss: 0.4658 - val_loss: 0.5672
# Epoch 40/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.4124 - val_loss: 0.5342
# Epoch 41/50
# 319/319 [==============================] - 160s 501ms/step - loss: 0.4148 - val_loss: 0.5596
# Epoch 42/50
# 319/319 [==============================] - 163s 511ms/step - loss: 0.4592 - val_loss: 0.5943
# Epoch 43/50
# 319/319 [==============================] - 161s 506ms/step - loss: 0.3967 - val_loss: 0.5120
# Epoch 44/50
# 319/319 [==============================] - 162s 508ms/step - loss: 0.3242 - val_loss: 0.5174
# Epoch 45/50
# 319/319 [==============================] - 163s 512ms/step - loss: 0.3882 - val_loss: 0.5206
# Epoch 46/50
# 319/319 [==============================] - 163s 512ms/step - loss: 0.3117 - val_loss: 0.5050
# Epoch 47/50
# 319/319 [==============================] - 162s 508ms/step - loss: 0.2684 - val_loss: 0.4989
# Epoch 48/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.3064 - val_loss: 0.5194
# Epoch 49/50
# 319/319 [==============================] - 163s 509ms/step - loss: 0.2310 - val_loss: 0.5163
# Epoch 50/50
# 319/319 [==============================] - 163s 510ms/step - loss: 0.2259 - val_loss: 0.5085
# CPU times: user 2h 32min 35s, sys: 29min 16s, total: 3h 1min 51s
# Wall time: 3h 20min 25s

# %% [markdown]
# #### Save and load train stats/logs/history

# %%
logs = model.history.history.copy()

logs['train_loss'] = logs.pop('loss')
logs['train_size'] = train_generator.get_size()
logs['val_size'] = val_generator.get_size()
logs['rand_seed'] = config.RAND_SEED
logs['shuffle'] = config.SHUFFLE
logs['loss_name'] = config.LOSS_NAME
logs['img_dim'] = config.IMG_DIM
logs['patch_dim'] = config.PATCH_DIM
logs['patches_per_image'] = config.PATCHES_PER_IMAGE
logs['density_map_sigma'] = config.GT_SIGMA
logs['density_map_multiplication_factor'] = config.DENSITY_MAP_MULTIPLICATION_FACTOR
logs['sub_experiment_name'] = config.SUB_EXPERIMENT_NAME
logs['architecture'] = config.ARCHITECTURE_NAME

# %%
write_json(logs, config.LOGS_FILENAME)
logs = read_json(config.LOGS_FILENAME)

print(f'min val_loss: {np.min(logs["val_loss"]):.4f}, epoch: {1 + np.argmin(logs["val_loss"])}')

plot_logs(logs['train_loss'], logs['val_loss'], f'{config.LOSS_NAME} loss (density maps)')

plot_logs(logs['train_mae'], logs['val_mae'], f'Mean_absolute_error (counts)')
plot_logs(logs['train_rmse'], logs['val_rmse'], f'RMSE (counts)')
plot_logs(logs['train_underestimate'], logs['val_underestimate'], f'Underestimate (% from GT counts)')
plot_logs(logs['train_overestimate'], logs['val_overestimate'], f'Overestimate (% from GT counts)')
plot_logs(logs['train_difference'], logs['val_difference'], f'Difference (% from GT counts)')
# Out:
# min val_loss: 0.4989, epoch: 47
