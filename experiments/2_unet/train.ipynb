# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('../..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os
import warnings

from keras.callbacks import ModelCheckpoint, Callback
from neural_networks.unet import UNet
from neural_networks.keras_utils import EvalMetricsCallback
from utils.data.data_generator import DataGenerator
from utils.data.data_ops import move_val_split_to_train
from utils.data.data_ops import create_val_split_from_train
from utils.input_output.io import read_json, write_json
from utils.visualization.vis import plot_logs
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load the dataset

# %% [markdown]
# #### Create validation split from the initial training data

# %%
move_val_split_to_train(config.VAL_PATH, config.TRAIN_PATH)
create_val_split_from_train(config.TRAIN_PATH, config.VAL_PATH, config.VAL_SIZE, config.RAND_SEED)

# %%
train_params = {
    'dim': config.PATCH_DIM,
    'batch_size': config.BATCH_SIZE,
    'patches_per_image': config.PATCHES_PER_IMAGE,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': config.SHUFFLE
}

val_params = {
    'dim': config.IMG_DIM,
    'batch_size': 1,
    'patches_per_image': 1,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': False
}

eval_params = val_params.copy()

# %%
train_generator = DataGenerator(config.DATASET_PATH, 'train', **train_params)
val_generator = DataGenerator(config.DATASET_PATH, 'val', **val_params)

### for eval
train_generator_for_eval = DataGenerator(config.DATASET_PATH, 'train', **eval_params)
val_generator_for_eval = DataGenerator(config.DATASET_PATH, 'val', **eval_params)

# %% [markdown]
# ## 3. Instantiate a UNet

# %%
model = UNet(loss_name=config.LOSS_NAME)

# %% [markdown]
# ## 4. Train the model

# %%
# !rm -rf $config.CHECKPOINTS_PATH
# !rm -rf $config.LOGS_PATH
os.makedirs(config.CHECKPOINTS_PATH)
os.makedirs(config.LOGS_PATH)

# %%
# %%time
eval_metrics_callback = EvalMetricsCallback(config.DENSITY_MAP_MULTIPLICATION_FACTOR,
                                            train_generator_for_eval,
                                            val_generator_for_eval)

model_checkpoint = ModelCheckpoint(config.CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   save_best_only=True)

model_history = model.fit_generator(generator=train_generator,
                                    validation_data=val_generator,
                                    epochs=config.EPOCHS,
                                    callbacks=[model_checkpoint,
                                               eval_metrics_callback],
                                    verbose=1)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 8s 473ms/step - loss: 0.2146 - val_loss: 0.1103
# Epoch 2/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0958 - val_loss: 0.0907
# Epoch 3/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0845 - val_loss: 0.0816
# Epoch 4/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0745 - val_loss: 0.0691
# Epoch 5/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0697 - val_loss: 0.0696
# Epoch 6/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0633 - val_loss: 0.0627
# Epoch 7/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0625 - val_loss: 0.0740
# Epoch 8/100
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0689 - val_loss: 0.0666
# Epoch 9/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0590 - val_loss: 0.0560
# Epoch 10/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0543 - val_loss: 0.0535
# Epoch 11/100
# 16/16 [==============================] - 3s 211ms/step - loss: 0.0521 - val_loss: 0.0532
# Epoch 12/100
# 16/16 [==============================] - 3s 211ms/step - loss: 0.0496 - val_loss: 0.0506
# Epoch 13/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0504 - val_loss: 0.0590
# Epoch 14/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0500 - val_loss: 0.0479
# Epoch 15/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0469 - val_loss: 0.0555
# Epoch 16/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0481 - val_loss: 0.0481
# Epoch 17/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0466 - val_loss: 0.0560
# Epoch 18/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0558 - val_loss: 0.0562
# Epoch 19/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0547 - val_loss: 0.0487
# Epoch 20/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0464 - val_loss: 0.0470
# Epoch 21/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0470 - val_loss: 0.0512
# Epoch 22/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0452 - val_loss: 0.0484
# Epoch 23/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0442 - val_loss: 0.0466
# Epoch 24/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0477 - val_loss: 0.0504
# Epoch 25/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0440 - val_loss: 0.0455
# Epoch 26/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0423 - val_loss: 0.0442
# Epoch 27/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0412 - val_loss: 0.0442
# Epoch 28/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0408 - val_loss: 0.0438
# Epoch 29/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0403 - val_loss: 0.0433
# Epoch 30/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0392 - val_loss: 0.0456
# Epoch 31/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0409 - val_loss: 0.0428
# Epoch 32/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0390 - val_loss: 0.0431
# Epoch 33/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0398 - val_loss: 0.0433
# Epoch 34/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0391 - val_loss: 0.0431
# Epoch 35/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0400 - val_loss: 0.0430
# Epoch 36/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0381 - val_loss: 0.0428
# Epoch 37/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0377 - val_loss: 0.0421
# Epoch 38/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0459 - val_loss: 0.0477
# Epoch 39/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0431 - val_loss: 0.0460
# Epoch 40/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0392 - val_loss: 0.0471
# Epoch 41/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0402 - val_loss: 0.0463
# Epoch 42/100
# 16/16 [==============================] - 3s 216ms/step - loss: 0.0422 - val_loss: 0.0432
# Epoch 43/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0399 - val_loss: 0.0426
# Epoch 44/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0421 - val_loss: 0.0459
# Epoch 45/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0390 - val_loss: 0.0431
# Epoch 46/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0376 - val_loss: 0.0431
# Epoch 47/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0376 - val_loss: 0.0422
# Epoch 48/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0388 - val_loss: 0.0418
# Epoch 49/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0394 - val_loss: 0.0423
# Epoch 50/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0371 - val_loss: 0.0422
# Epoch 51/100
# 16/16 [==============================] - 3s 217ms/step - loss: 0.0380 - val_loss: 0.0430
# Epoch 52/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0381 - val_loss: 0.0433
# Epoch 53/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0372 - val_loss: 0.0422
# Epoch 54/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0359 - val_loss: 0.0417
# Epoch 55/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0356 - val_loss: 0.0413
# Epoch 56/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0338 - val_loss: 0.0452
# Epoch 57/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0356 - val_loss: 0.0447
# Epoch 58/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0347 - val_loss: 0.0415
# Epoch 59/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0333 - val_loss: 0.0411
# Epoch 60/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0343 - val_loss: 0.0431
# Epoch 61/100
# 16/16 [==============================] - 3s 215ms/step - loss: 0.0339 - val_loss: 0.0434
# Epoch 62/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0346 - val_loss: 0.0460
# Epoch 63/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0357 - val_loss: 0.0413
# Epoch 64/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0348 - val_loss: 0.0416
# Epoch 65/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0328 - val_loss: 0.0414
# Epoch 66/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0335 - val_loss: 0.0459
# Epoch 67/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0331 - val_loss: 0.0412
# Epoch 68/100
# 16/16 [==============================] - 3s 215ms/step - loss: 0.0364 - val_loss: 0.0418
# Epoch 69/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0325 - val_loss: 0.0419
# Epoch 70/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0309 - val_loss: 0.0420
# Epoch 71/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0315 - val_loss: 0.0411
# Epoch 72/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0342 - val_loss: 0.0420
# Epoch 73/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0325 - val_loss: 0.0411
# Epoch 74/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0304 - val_loss: 0.0410
# Epoch 75/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0299 - val_loss: 0.0425
# Epoch 76/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0307 - val_loss: 0.0418
# Epoch 77/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0307 - val_loss: 0.0411
# Epoch 78/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0302 - val_loss: 0.0415
# Epoch 79/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0293 - val_loss: 0.0410
# Epoch 80/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0293 - val_loss: 0.0404
# Epoch 81/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.0301 - val_loss: 0.0413
# Epoch 82/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0302 - val_loss: 0.0419
# Epoch 83/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0285 - val_loss: 0.0431
# Epoch 84/100
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0293 - val_loss: 0.0408
# Epoch 85/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0303 - val_loss: 0.0413
# Epoch 86/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0307 - val_loss: 0.0442
# Epoch 87/100
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0294 - val_loss: 0.0410
# Epoch 88/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0289 - val_loss: 0.0414
# Epoch 89/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0282 - val_loss: 0.0405
# Epoch 90/100
# 16/16 [==============================] - 3s 211ms/step - loss: 0.0274 - val_loss: 0.0406
# Epoch 91/100
# 16/16 [==============================] - 3s 217ms/step - loss: 0.0272 - val_loss: 0.0414
# Epoch 92/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0261 - val_loss: 0.0417
# Epoch 93/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0268 - val_loss: 0.0404
# Epoch 94/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0277 - val_loss: 0.0434
# Epoch 95/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0287 - val_loss: 0.0404
# Epoch 96/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0268 - val_loss: 0.0400
# Epoch 97/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0257 - val_loss: 0.0403
# Epoch 98/100
# 16/16 [==============================] - 3s 215ms/step - loss: 0.0273 - val_loss: 0.0418
# Epoch 99/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0280 - val_loss: 0.0413
# Epoch 100/100
# 16/16 [==============================] - 3s 215ms/step - loss: 0.0278 - val_loss: 0.0417
# CPU times: user 7min 34s, sys: 1min 15s, total: 8min 50s
# Wall time: 9min 12s

# %% [markdown]
# #### Save and load train stats/logs/history

# %%
logs = model.history.history.copy()

logs['train_loss'] = logs.pop('loss')
logs['train_size'] = train_generator.get_size()
logs['val_size'] = val_generator.get_size()
logs['rand_seed'] = config.RAND_SEED
logs['shuffle'] = config.SHUFFLE
logs['loss_name'] = config.LOSS_NAME
logs['img_dim'] = config.IMG_DIM
logs['patch_dim'] = config.PATCH_DIM
logs['patches_per_image'] = config.PATCHES_PER_IMAGE
logs['density_map_sigma'] = config.GT_SIGMA
logs['density_map_multiplication_factor'] = config.DENSITY_MAP_MULTIPLICATION_FACTOR
logs['sub_experiment_name'] = config.SUB_EXPERIMENT_NAME
logs['architecture'] = config.ARCHITECTURE_NAME

# %%
write_json(logs, config.LOGS_FILENAME)
logs = read_json(config.LOGS_FILENAME)

print(f'min val_loss: {np.min(logs["val_loss"]):.4f}, epoch: {1 + np.argmin(logs["val_loss"])}')

plot_logs(logs['train_loss'], logs['val_loss'], f'{config.LOSS_NAME} loss (density maps)')

plot_logs(logs['train_mae'], logs['val_mae'], f'Mean_absolute_error (counts)')
plot_logs(logs['train_rmse'], logs['val_rmse'], f'RMSE (counts)')
plot_logs(logs['train_underestimate'], logs['val_underestimate'], f'Underestimate (% from GT counts)')
plot_logs(logs['train_overestimate'], logs['val_overestimate'], f'Overestimate (% from GT counts)')
plot_logs(logs['train_difference'], logs['val_difference'], f'Difference (% from GT counts)')
# Out:
# min val_loss: 0.0400, epoch: 96
