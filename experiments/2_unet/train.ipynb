# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('../..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os
import warnings

from keras.callbacks import ModelCheckpoint, Callback
from neural_networks.unet import UNet
from neural_networks.keras_utils import EvalMetricsCallback
from utils.data.data_generator import DataGenerator
from utils.data.data_ops import move_val_split_to_train
from utils.data.data_ops import create_val_split_from_train
from utils.input_output.io import read_json, write_json
from utils.visualization.vis import plot_logs
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load the dataset

# %% [markdown]
# #### Create validation split from the initial training data

# %%
move_val_split_to_train(config.VAL_PATH, config.TRAIN_PATH)
create_val_split_from_train(config.TRAIN_PATH, config.VAL_PATH, config.VAL_SIZE, config.RAND_SEED)

# %%
train_params = {
    'dim': config.PATCH_DIM,
    'batch_size': config.BATCH_SIZE,
    'patches_per_image': config.PATCHES_PER_IMAGE,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': config.SHUFFLE
}

val_params = {
    'dim': config.IMG_DIM,
    'batch_size': 1,
    'patches_per_image': 1,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': False
}

eval_params = val_params.copy()

# %%
train_generator = DataGenerator(config.DATASET_PATH, 'train', **train_params)
val_generator = DataGenerator(config.DATASET_PATH, 'val', **val_params)

### for eval
train_generator_for_eval = DataGenerator(config.DATASET_PATH, 'train', **eval_params)
val_generator_for_eval = DataGenerator(config.DATASET_PATH, 'val', **eval_params)

# %% [markdown]
# ## 3. Instantiate a UNet

# %%
model = UNet(loss_name=config.LOSS_NAME)

# %% [markdown]
# ## 4. Train the model

# %%
# !rm -rf $config.CHECKPOINTS_PATH
# !rm -rf $config.LOGS_PATH
os.makedirs(config.CHECKPOINTS_PATH)
os.makedirs(config.LOGS_PATH)

# %%
# %%time
eval_metrics_callback = EvalMetricsCallback(config.DENSITY_MAP_MULTIPLICATION_FACTOR,
                                            train_generator_for_eval,
                                            val_generator_for_eval)

model_checkpoint = ModelCheckpoint(config.CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   save_best_only=True)

model_history = model.fit_generator(generator=train_generator,
                                    validation_data=val_generator,
                                    epochs=config.EPOCHS,
                                    callbacks=[model_checkpoint,
                                               eval_metrics_callback],
                                    verbose=1)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 7s 467ms/step - loss: 0.1157 - val_loss: 0.0377
# Epoch 2/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0287 - val_loss: 0.0259
# Epoch 3/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0204 - val_loss: 0.0216
# Epoch 4/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0177 - val_loss: 0.0193
# Epoch 5/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0148 - val_loss: 0.0174
# Epoch 6/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0130 - val_loss: 0.0195
# Epoch 7/100
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0137 - val_loss: 0.0150
# Epoch 8/100
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0115 - val_loss: 0.0151
# Epoch 9/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0127 - val_loss: 0.0147
# Epoch 10/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0109 - val_loss: 0.0138
# Epoch 11/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0101 - val_loss: 0.0124
# Epoch 12/100
# 16/16 [==============================] - 3s 211ms/step - loss: 0.0092 - val_loss: 0.0120
# Epoch 13/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0090 - val_loss: 0.0113
# Epoch 14/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0084 - val_loss: 0.0123
# Epoch 15/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0090 - val_loss: 0.0122
# Epoch 16/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0095 - val_loss: 0.0114
# Epoch 17/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0095 - val_loss: 0.0123
# Epoch 18/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0083 - val_loss: 0.0107
# Epoch 19/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0078 - val_loss: 0.0110
# Epoch 20/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0080 - val_loss: 0.0111
# Epoch 21/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0092 - val_loss: 0.0108
# Epoch 22/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0077 - val_loss: 0.0105
# Epoch 23/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0075 - val_loss: 0.0103
# Epoch 24/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0068 - val_loss: 0.0100
# Epoch 25/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0068 - val_loss: 0.0095
# Epoch 26/100
# 16/16 [==============================] - 3s 211ms/step - loss: 0.0073 - val_loss: 0.0127
# Epoch 27/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0075 - val_loss: 0.0100
# Epoch 28/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0073 - val_loss: 0.0103
# Epoch 29/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0065 - val_loss: 0.0099
# Epoch 30/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0067 - val_loss: 0.0097
# Epoch 31/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0062 - val_loss: 0.0100
# Epoch 32/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0073 - val_loss: 0.0120
# Epoch 33/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0063 - val_loss: 0.0094
# Epoch 34/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0062 - val_loss: 0.0098
# Epoch 35/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0066 - val_loss: 0.0089
# Epoch 36/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0062 - val_loss: 0.0095
# Epoch 37/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0064 - val_loss: 0.0096
# Epoch 38/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0066 - val_loss: 0.0099
# Epoch 39/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0063 - val_loss: 0.0092
# Epoch 40/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0058 - val_loss: 0.0103
# Epoch 41/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0073 - val_loss: 0.0125
# Epoch 42/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0073 - val_loss: 0.0100
# Epoch 43/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0065 - val_loss: 0.0090
# Epoch 44/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0062 - val_loss: 0.0089
# Epoch 45/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0056 - val_loss: 0.0088
# Epoch 46/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0060 - val_loss: 0.0099
# Epoch 47/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0056 - val_loss: 0.0094
# Epoch 48/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0054 - val_loss: 0.0095
# Epoch 49/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 50/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0053 - val_loss: 0.0089
# Epoch 51/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0056 - val_loss: 0.0120
# Epoch 52/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0065 - val_loss: 0.0101
# Epoch 53/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0058 - val_loss: 0.0105
# Epoch 54/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0055 - val_loss: 0.0090
# Epoch 55/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0050 - val_loss: 0.0092
# Epoch 56/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0049 - val_loss: 0.0093
# Epoch 57/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0047 - val_loss: 0.0094
# Epoch 58/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0051 - val_loss: 0.0100
# Epoch 59/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 60/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0048 - val_loss: 0.0089
# Epoch 61/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0043 - val_loss: 0.0088
# Epoch 62/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0054 - val_loss: 0.0093
# Epoch 63/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0054 - val_loss: 0.0095
# Epoch 64/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0046 - val_loss: 0.0086
# Epoch 65/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0044 - val_loss: 0.0086
# Epoch 66/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0046 - val_loss: 0.0087
# Epoch 67/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0044 - val_loss: 0.0093
# Epoch 68/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0041 - val_loss: 0.0094
# Epoch 69/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0042 - val_loss: 0.0089
# Epoch 70/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0041 - val_loss: 0.0092
# Epoch 71/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0044 - val_loss: 0.0087
# Epoch 72/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0046 - val_loss: 0.0102
# Epoch 73/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0068 - val_loss: 0.0103
# Epoch 74/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0053 - val_loss: 0.0088
# Epoch 75/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0044 - val_loss: 0.0084
# Epoch 76/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0040 - val_loss: 0.0087
# Epoch 77/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0041 - val_loss: 0.0097
# Epoch 78/100
# 16/16 [==============================] - 3s 216ms/step - loss: 0.0041 - val_loss: 0.0092
# Epoch 79/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0040 - val_loss: 0.0091
# Epoch 80/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0038 - val_loss: 0.0087
# Epoch 81/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.0042 - val_loss: 0.0094
# Epoch 82/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0045 - val_loss: 0.0088
# Epoch 83/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0040 - val_loss: 0.0097
# Epoch 84/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0044 - val_loss: 0.0088
# Epoch 85/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0049 - val_loss: 0.0090
# Epoch 86/100
# 16/16 [==============================] - 3s 211ms/step - loss: 0.0043 - val_loss: 0.0085
# Epoch 87/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0035 - val_loss: 0.0087
# Epoch 88/100
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0033 - val_loss: 0.0087
# Epoch 89/100
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0034 - val_loss: 0.0091
# Epoch 90/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0035 - val_loss: 0.0108
# Epoch 91/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.0038 - val_loss: 0.0095
# Epoch 92/100
# 16/16 [==============================] - 3s 211ms/step - loss: 0.0035 - val_loss: 0.0091
# Epoch 93/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0033 - val_loss: 0.0089
# Epoch 94/100
# 16/16 [==============================] - 3s 212ms/step - loss: 0.0033 - val_loss: 0.0085
# Epoch 95/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0032 - val_loss: 0.0091
# Epoch 96/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0033 - val_loss: 0.0091
# Epoch 97/100
# 16/16 [==============================] - 3s 215ms/step - loss: 0.0032 - val_loss: 0.0084
# Epoch 98/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0031 - val_loss: 0.0087
# Epoch 99/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0030 - val_loss: 0.0086
# Epoch 100/100
# 16/16 [==============================] - 3s 214ms/step - loss: 0.0029 - val_loss: 0.0091
# CPU times: user 7min 32s, sys: 1min 16s, total: 8min 48s
# Wall time: 9min 8s

# %% [markdown]
# #### Save and load train stats/logs/history

# %%
logs = model.history.history.copy()

logs['train_loss'] = logs.pop('loss')
logs['train_size'] = train_generator.get_size()
logs['val_size'] = val_generator.get_size()
logs['rand_seed'] = config.RAND_SEED
logs['shuffle'] = config.SHUFFLE
logs['loss_name'] = config.LOSS_NAME
logs['img_dim'] = config.IMG_DIM
logs['patch_dim'] = config.PATCH_DIM
logs['patches_per_image'] = config.PATCHES_PER_IMAGE
logs['density_map_sigma'] = config.GT_SIGMA
logs['density_map_multiplication_factor'] = config.DENSITY_MAP_MULTIPLICATION_FACTOR
logs['sub_experiment_name'] = config.SUB_EXPERIMENT_NAME
logs['architecture'] = config.ARCHITECTURE_NAME

# %%
write_json(logs, config.LOGS_FILENAME)
logs = read_json(config.LOGS_FILENAME)

print(f'min val_loss: {np.min(logs["val_loss"]):.4f}, epoch: {1 + np.argmin(logs["val_loss"])}')

plot_logs(logs['train_loss'], logs['val_loss'], f'{config.LOSS_NAME} loss (density maps)')

plot_logs(logs['train_mae'], logs['val_mae'], f'Mean_absolute_error (counts)')
plot_logs(logs['train_rmse'], logs['val_rmse'], f'RMSE (counts)')
plot_logs(logs['train_underestimate'], logs['val_underestimate'], f'Underestimate (% from GT counts)')
plot_logs(logs['train_overestimate'], logs['val_overestimate'], f'Overestimate (% from GT counts)')
plot_logs(logs['train_difference'], logs['val_difference'], f'Difference (% from GT counts)')
# Out:
# min val_loss: 0.0084, epoch: 97
