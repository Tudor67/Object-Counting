# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('../..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os
import warnings

from keras.callbacks import ModelCheckpoint, Callback
from neural_networks.unet import UNet
from neural_networks.keras_utils import EvalMetricsCallback
from utils.data.data_generator import DataGenerator
from utils.data.data_ops import move_val_split_to_train
from utils.data.data_ops import create_val_split_from_train
from utils.input_output.io import read_json, write_json
from utils.visualization.vis import plot_logs
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load the dataset

# %% [markdown]
# #### Create validation split from the initial training data

# %%
move_val_split_to_train(config.VAL_PATH, config.TRAIN_PATH)
create_val_split_from_train(config.TRAIN_PATH, config.VAL_PATH, config.VAL_SIZE, config.RAND_SEED)

# %%
train_params = {
    'dim': config.PATCH_DIM,
    'batch_size': config.BATCH_SIZE,
    'patches_per_image': config.PATCHES_PER_IMAGE,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': config.SHUFFLE,
    'ignored_images': config.IGNORED_IMAGES
}

val_params = {
    'dim': config.IMG_DIM,
    'batch_size': 1,
    'patches_per_image': 1,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': False
}

eval_params = val_params.copy()

# %%
train_generator = DataGenerator(config.DATASET_PATH, 'train', **train_params)
val_generator = DataGenerator(config.DATASET_PATH, 'val', **val_params)

### for eval
train_generator_for_eval = DataGenerator(config.DATASET_PATH, 'train', **eval_params)
val_generator_for_eval = DataGenerator(config.DATASET_PATH, 'val', **eval_params)

# %% [markdown]
# ## 3. Instantiate a UNet

# %%
model = UNet(loss_name=config.LOSS_NAME)

# %% [markdown]
# ## 4. Train the model

# %%
# !rm -rf $config.CHECKPOINTS_PATH
# !rm -rf $config.LOGS_PATH
os.makedirs(config.CHECKPOINTS_PATH)
os.makedirs(config.LOGS_PATH)

# %%
# %%time
eval_metrics_callback = EvalMetricsCallback(config.DENSITY_MAP_MULTIPLICATION_FACTOR,
                                            train_generator_for_eval,
                                            val_generator_for_eval)

model_checkpoint = ModelCheckpoint(config.CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   save_best_only=True)

model_history = model.fit_generator(generator=train_generator,
                                    validation_data=val_generator,
                                    epochs=config.EPOCHS,
                                    callbacks=[model_checkpoint,
                                               eval_metrics_callback],
                                    verbose=1)
# Out:
# Epoch 1/50
# 319/319 [==============================] - 129s 406ms/step - loss: 0.1810 - val_loss: 0.2130
# Epoch 2/50
# 319/319 [==============================] - 120s 376ms/step - loss: 0.1686 - val_loss: 0.2118
# Epoch 3/50
# 319/319 [==============================] - 120s 377ms/step - loss: 0.1588 - val_loss: 0.2083
# Epoch 4/50
# 319/319 [==============================] - 120s 377ms/step - loss: 0.1640 - val_loss: 0.1947
# Epoch 5/50
# 319/319 [==============================] - 121s 379ms/step - loss: 0.1685 - val_loss: 0.1969
# Epoch 6/50
# 319/319 [==============================] - 121s 380ms/step - loss: 0.1501 - val_loss: 0.2012
# Epoch 7/50
# 319/319 [==============================] - 121s 380ms/step - loss: 0.1546 - val_loss: 0.1988
# Epoch 8/50
# 319/319 [==============================] - 122s 381ms/step - loss: 0.1586 - val_loss: 0.1895
# Epoch 9/50
# 319/319 [==============================] - 121s 381ms/step - loss: 0.1573 - val_loss: 0.1839
# Epoch 10/50
# 319/319 [==============================] - 122s 381ms/step - loss: 0.1337 - val_loss: 0.1695
# Epoch 11/50
# 319/319 [==============================] - 122s 381ms/step - loss: 0.1352 - val_loss: 0.1635
# Epoch 12/50
# 319/319 [==============================] - 122s 382ms/step - loss: 0.1324 - val_loss: 0.1523
# Epoch 13/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.1176 - val_loss: 0.1748
# Epoch 14/50
# 319/319 [==============================] - 122s 383ms/step - loss: 0.1203 - val_loss: 0.1329
# Epoch 15/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.1142 - val_loss: 0.1187
# Epoch 16/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.1012 - val_loss: 0.1186
# Epoch 17/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0980 - val_loss: 0.1329
# Epoch 18/50
# 319/319 [==============================] - 123s 385ms/step - loss: 0.0921 - val_loss: 0.1125
# Epoch 19/50
# 319/319 [==============================] - 123s 385ms/step - loss: 0.1029 - val_loss: 0.2032
# Epoch 20/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.1041 - val_loss: 0.1102
# Epoch 21/50
# 319/319 [==============================] - 122s 382ms/step - loss: 0.0874 - val_loss: 0.1161
# Epoch 22/50
# 319/319 [==============================] - 122s 382ms/step - loss: 0.0922 - val_loss: 0.0950
# Epoch 23/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0803 - val_loss: 0.0941
# Epoch 24/50
# 319/319 [==============================] - 122s 382ms/step - loss: 0.0862 - val_loss: 0.0957
# Epoch 25/50
# 319/319 [==============================] - 123s 385ms/step - loss: 0.0790 - val_loss: 0.1123
# Epoch 26/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0934 - val_loss: 0.0987
# Epoch 27/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0768 - val_loss: 0.0935
# Epoch 28/50
# 319/319 [==============================] - 122s 381ms/step - loss: 0.0790 - val_loss: 0.1069
# Epoch 29/50
# 319/319 [==============================] - 122s 382ms/step - loss: 0.0794 - val_loss: 0.1079
# Epoch 30/50
# 319/319 [==============================] - 122s 381ms/step - loss: 0.0768 - val_loss: 0.1026
# Epoch 31/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0830 - val_loss: 0.0896
# Epoch 32/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0693 - val_loss: 0.0861
# Epoch 33/50
# 319/319 [==============================] - 123s 385ms/step - loss: 0.0687 - val_loss: 0.0871
# Epoch 34/50
# 319/319 [==============================] - 122s 383ms/step - loss: 0.0803 - val_loss: 0.0921
# Epoch 35/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0768 - val_loss: 0.0972
# Epoch 36/50
# 319/319 [==============================] - 122s 383ms/step - loss: 0.0692 - val_loss: 0.0864
# Epoch 37/50
# 319/319 [==============================] - 122s 382ms/step - loss: 0.0683 - val_loss: 0.0990
# Epoch 38/50
# 319/319 [==============================] - 122s 382ms/step - loss: 0.0655 - val_loss: 0.0977
# Epoch 39/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0689 - val_loss: 0.0891
# Epoch 40/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0726 - val_loss: 0.0838
# Epoch 41/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0675 - val_loss: 0.0850
# Epoch 42/50
# 319/319 [==============================] - 123s 384ms/step - loss: 0.0673 - val_loss: 0.0844
# Epoch 43/50
# 319/319 [==============================] - 123s 384ms/step - loss: 0.0666 - val_loss: 0.0896
# Epoch 44/50
# 319/319 [==============================] - 123s 385ms/step - loss: 0.0674 - val_loss: 0.0843
# Epoch 45/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0663 - val_loss: 0.0960
# Epoch 46/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0609 - val_loss: 0.0818
# Epoch 47/50
# 319/319 [==============================] - 122s 383ms/step - loss: 0.0688 - val_loss: 0.0828
# Epoch 48/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0637 - val_loss: 0.0856
# Epoch 49/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0620 - val_loss: 0.0886
# Epoch 50/50
# 319/319 [==============================] - 122s 384ms/step - loss: 0.0661 - val_loss: 0.0807
# CPU times: user 2h 15min 42s, sys: 26min 34s, total: 2h 42min 17s
# Wall time: 2h 53min 40s

# %% [markdown]
# #### Save and load train stats/logs/history

# %%
logs = model.history.history.copy()

logs['train_loss'] = logs.pop('loss')
logs['train_size'] = train_generator.get_size()
logs['val_size'] = val_generator.get_size()
logs['rand_seed'] = config.RAND_SEED
logs['shuffle'] = config.SHUFFLE
logs['loss_name'] = config.LOSS_NAME
logs['img_dim'] = config.IMG_DIM
logs['patch_dim'] = config.PATCH_DIM
logs['patches_per_image'] = config.PATCHES_PER_IMAGE
logs['density_map_sigma'] = config.GT_SIGMA
logs['density_map_multiplication_factor'] = config.DENSITY_MAP_MULTIPLICATION_FACTOR
logs['sub_experiment_name'] = config.SUB_EXPERIMENT_NAME
logs['architecture'] = config.ARCHITECTURE_NAME

# %%
write_json(logs, config.LOGS_FILENAME)
logs = read_json(config.LOGS_FILENAME)

print(f'min val_loss: {np.min(logs["val_loss"]):.4f}, epoch: {1 + np.argmin(logs["val_loss"])}')

plot_logs(logs['train_loss'], logs['val_loss'], f'{config.LOSS_NAME} loss (density maps)')

plot_logs(logs['train_mae'], logs['val_mae'], f'Mean_absolute_error (counts)')
plot_logs(logs['train_rmse'], logs['val_rmse'], f'RMSE (counts)')
plot_logs(logs['train_underestimate'], logs['val_underestimate'], f'Underestimate (% from GT counts)')
plot_logs(logs['train_overestimate'], logs['val_overestimate'], f'Overestimate (% from GT counts)')
plot_logs(logs['train_difference'], logs['val_difference'], f'Difference (% from GT counts)')
# Out:
# min val_loss: 0.0807, epoch: 50
