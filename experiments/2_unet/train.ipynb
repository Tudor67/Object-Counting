# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('../..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os
import warnings

from keras.callbacks import ModelCheckpoint, Callback
from neural_networks.unet import UNet
from neural_networks.keras_utils import EvalMetricsCallback
from utils.data.data_generator import DataGenerator
from utils.data.data_ops import move_val_split_to_train
from utils.data.data_ops import create_val_split_from_train
from utils.input_output.io import read_json, write_json
from utils.visualization.vis import plot_logs
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load the dataset

# %% [markdown]
# #### Create validation split from the initial training data

# %%
move_val_split_to_train(config.VAL_PATH, config.TRAIN_PATH)
create_val_split_from_train(config.TRAIN_PATH, config.VAL_PATH, config.VAL_SIZE, config.RAND_SEED)

# %%
train_params = {
    'dim': config.PATCH_DIM,
    'batch_size': config.BATCH_SIZE,
    'patches_per_image': config.PATCHES_PER_IMAGE,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': config.SHUFFLE
}

val_params = {
    'dim': config.IMG_DIM,
    'batch_size': 1,
    'patches_per_image': 1,
    'density_map_multiplication_factor': config.DENSITY_MAP_MULTIPLICATION_FACTOR,
    'shuffle': False
}

eval_params = val_params.copy()

# %%
train_generator = DataGenerator(config.DATASET_PATH, 'train', **train_params)
val_generator = DataGenerator(config.DATASET_PATH, 'val', **val_params)

### for eval
train_generator_for_eval = DataGenerator(config.DATASET_PATH, 'train', **eval_params)
val_generator_for_eval = DataGenerator(config.DATASET_PATH, 'val', **eval_params)

# %% [markdown]
# ## 3. Instantiate a UNet

# %%
model = UNet(loss_name=config.LOSS_NAME)

# %% [markdown]
# ## 4. Train the model

# %%
# !rm -rf $config.CHECKPOINTS_PATH
# !rm -rf $config.LOGS_PATH
os.makedirs(config.CHECKPOINTS_PATH)
os.makedirs(config.LOGS_PATH)

# %%
# %%time
eval_metrics_callback = EvalMetricsCallback(config.DENSITY_MAP_MULTIPLICATION_FACTOR,
                                            train_generator_for_eval,
                                            val_generator_for_eval)

model_checkpoint = ModelCheckpoint(config.CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   save_best_only=True)

model_history = model.fit_generator(generator=train_generator,
                                    validation_data=val_generator,
                                    epochs=config.EPOCHS,
                                    callbacks=[model_checkpoint,
                                               eval_metrics_callback],
                                    verbose=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 9s 2s/step - loss: 0.1293 - val_loss: 0.0314
# Epoch 2/100
# 4/4 [==============================] - 3s 699ms/step - loss: 0.0299 - val_loss: 0.0277
# Epoch 3/100
# 4/4 [==============================] - 3s 699ms/step - loss: 0.0203 - val_loss: 0.0179
# Epoch 4/100
# 4/4 [==============================] - 3s 698ms/step - loss: 0.0153 - val_loss: 0.0156
# Epoch 5/100
# 4/4 [==============================] - 3s 701ms/step - loss: 0.0134 - val_loss: 0.0139
# Epoch 6/100
# 4/4 [==============================] - 3s 701ms/step - loss: 0.0118 - val_loss: 0.0124
# Epoch 7/100
# 4/4 [==============================] - 3s 702ms/step - loss: 0.0104 - val_loss: 0.0108
# Epoch 8/100
# 4/4 [==============================] - 3s 704ms/step - loss: 0.0095 - val_loss: 0.0114
# Epoch 9/100
# 4/4 [==============================] - 3s 700ms/step - loss: 0.0092 - val_loss: 0.0101
# Epoch 10/100
# 4/4 [==============================] - 3s 698ms/step - loss: 0.0085 - val_loss: 0.0093
# Epoch 11/100
# 4/4 [==============================] - 3s 743ms/step - loss: 0.0085 - val_loss: 0.0084
# Epoch 12/100
# 4/4 [==============================] - 3s 694ms/step - loss: 0.0078 - val_loss: 0.0079
# Epoch 13/100
# 4/4 [==============================] - 3s 714ms/step - loss: 0.0073 - val_loss: 0.0076
# Epoch 14/100
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0066 - val_loss: 0.0073
# Epoch 15/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0062 - val_loss: 0.0076
# Epoch 16/100
# 4/4 [==============================] - 3s 708ms/step - loss: 0.0059 - val_loss: 0.0070
# Epoch 17/100
# 4/4 [==============================] - 3s 709ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 18/100
# 4/4 [==============================] - 3s 706ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 19/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 20/100
# 4/4 [==============================] - 3s 708ms/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 21/100
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0049 - val_loss: 0.0059
# Epoch 22/100
# 4/4 [==============================] - 3s 724ms/step - loss: 0.0047 - val_loss: 0.0052
# Epoch 23/100
# 4/4 [==============================] - 3s 708ms/step - loss: 0.0044 - val_loss: 0.0056
# Epoch 24/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0043 - val_loss: 0.0056
# Epoch 25/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 26/100
# 4/4 [==============================] - 3s 706ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 27/100
# 4/4 [==============================] - 3s 709ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 28/100
# 4/4 [==============================] - 3s 708ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 29/100
# 4/4 [==============================] - 3s 708ms/step - loss: 0.0037 - val_loss: 0.0044
# Epoch 30/100
# 4/4 [==============================] - 3s 708ms/step - loss: 0.0036 - val_loss: 0.0045
# Epoch 31/100
# 4/4 [==============================] - 3s 709ms/step - loss: 0.0036 - val_loss: 0.0050
# Epoch 32/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 33/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 34/100
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 35/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0034 - val_loss: 0.0041
# Epoch 36/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0033 - val_loss: 0.0044
# Epoch 37/100
# 4/4 [==============================] - 3s 725ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 38/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0031 - val_loss: 0.0040
# Epoch 39/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0032 - val_loss: 0.0060
# Epoch 40/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 41/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 42/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 43/100
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0030 - val_loss: 0.0047
# Epoch 44/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0029 - val_loss: 0.0045
# Epoch 45/100
# 4/4 [==============================] - 3s 723ms/step - loss: 0.0028 - val_loss: 0.0039
# Epoch 46/100
# 4/4 [==============================] - 3s 709ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 47/100
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0027 - val_loss: 0.0042
# Epoch 48/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0029 - val_loss: 0.0041
# Epoch 49/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0029 - val_loss: 0.0040
# Epoch 50/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 51/100
# 4/4 [==============================] - 3s 714ms/step - loss: 0.0028 - val_loss: 0.0050
# Epoch 52/100
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0028 - val_loss: 0.0053
# Epoch 53/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0030 - val_loss: 0.0045
# Epoch 54/100
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0028 - val_loss: 0.0040
# Epoch 55/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0026 - val_loss: 0.0043
# Epoch 56/100
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0028 - val_loss: 0.0040
# Epoch 57/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 58/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0024 - val_loss: 0.0046
# Epoch 59/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 60/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 61/100
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 62/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 63/100
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 64/100
# 4/4 [==============================] - 3s 714ms/step - loss: 0.0019 - val_loss: 0.0044
# Epoch 65/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0026 - val_loss: 0.0063
# Epoch 66/100
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 67/100
# 4/4 [==============================] - 3s 718ms/step - loss: 0.0030 - val_loss: 0.0049
# Epoch 68/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0037 - val_loss: 0.0051
# Epoch 69/100
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0033 - val_loss: 0.0046
# Epoch 70/100
# 4/4 [==============================] - 3s 714ms/step - loss: 0.0030 - val_loss: 0.0044
# Epoch 71/100
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0025 - val_loss: 0.0042
# Epoch 72/100
# 4/4 [==============================] - 3s 718ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 73/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0022 - val_loss: 0.0038
# Epoch 74/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 75/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0018 - val_loss: 0.0040
# Epoch 76/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 77/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0016 - val_loss: 0.0041
# Epoch 78/100
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 79/100
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0018 - val_loss: 0.0050
# Epoch 80/100
# 4/4 [==============================] - 3s 720ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 81/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 82/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0016 - val_loss: 0.0039
# Epoch 83/100
# 4/4 [==============================] - 3s 706ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 84/100
# 4/4 [==============================] - 3s 708ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 85/100
# 4/4 [==============================] - 3s 708ms/step - loss: 0.0013 - val_loss: 0.0040
# Epoch 86/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 87/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0013 - val_loss: 0.0038
# Epoch 88/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0012 - val_loss: 0.0038
# Epoch 89/100
# 4/4 [==============================] - 3s 709ms/step - loss: 0.0011 - val_loss: 0.0039
# Epoch 90/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 91/100
# 4/4 [==============================] - 3s 723ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 92/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0015 - val_loss: 0.0038
# Epoch 93/100
# 4/4 [==============================] - 3s 709ms/step - loss: 0.0016 - val_loss: 0.0050
# Epoch 94/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0016 - val_loss: 0.0046
# Epoch 95/100
# 4/4 [==============================] - 3s 708ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 96/100
# 4/4 [==============================] - 3s 706ms/step - loss: 0.0011 - val_loss: 0.0040
# Epoch 97/100
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0011 - val_loss: 0.0038
# Epoch 98/100
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0010 - val_loss: 0.0043
# Epoch 99/100
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0011 - val_loss: 0.0038
# Epoch 100/100
# 4/4 [==============================] - 3s 710ms/step - loss: 8.9130e-04 - val_loss: 0.0039
# CPU times: user 6min 36s, sys: 1min 3s, total: 7min 40s
# Wall time: 7min 52s

# %% [markdown]
# #### Save and load train stats/logs/history

# %%
logs = model.history.history.copy()

logs['train_loss'] = logs.pop('loss')
logs['train_size'] = train_generator.get_size()
logs['val_size'] = val_generator.get_size()
logs['rand_seed'] = config.RAND_SEED
logs['shuffle'] = config.SHUFFLE
logs['loss_name'] = config.LOSS_NAME
logs['img_dim'] = config.IMG_DIM
logs['patch_dim'] = config.PATCH_DIM
logs['patches_per_image'] = config.PATCHES_PER_IMAGE
logs['density_map_sigma'] = config.GT_SIGMA
logs['density_map_multiplication_factor'] = config.DENSITY_MAP_MULTIPLICATION_FACTOR
logs['sub_experiment_name'] = config.SUB_EXPERIMENT_NAME
logs['architecture'] = config.ARCHITECTURE_NAME

# %%
write_json(logs, config.LOGS_FILENAME)
logs = read_json(config.LOGS_FILENAME)

print(f'min val_loss: {np.min(logs["val_loss"]):.4f}, epoch: {1 + np.argmin(logs["val_loss"])}')

plot_logs(logs['train_loss'], logs['val_loss'], f'{config.LOSS_NAME} loss (density maps)')

plot_logs(logs['train_mae'], logs['val_mae'], f'Mean_absolute_error (counts)')
plot_logs(logs['train_rmse'], logs['val_rmse'], f'RMSE (counts)')
plot_logs(logs['train_underestimate'], logs['val_underestimate'], f'Underestimate (% from GT counts)')
plot_logs(logs['train_overestimate'], logs['val_overestimate'], f'Overestimate (% from GT counts)')
plot_logs(logs['train_difference'], logs['val_difference'], f'Difference (% from GT counts)')
# Out:
# min val_loss: 0.0037, epoch: 81
